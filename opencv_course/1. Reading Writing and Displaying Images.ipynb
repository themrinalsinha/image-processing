# %%
# Required Imports

import numpy as np
from cv2 import cv2
from utils import showImage

# %%
# Loading our first image

image = cv2.imread('sample/input.jpg')
print(image.shape)
showImage(image)

image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
print(image.shape)
showImage(image)
# Out:
# (830, 1245, 3)
# (830, 1245)

# %%
# writing our first image
cv2.imwrite(image, )
